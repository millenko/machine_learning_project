# %% [markdown]
# # Predictions, part I
# - drop columns: no
# - normalization: no
# - hyperparameter tuning: no
# - one-hot encoding: yes, the dataset was found encoded
# - oversampling: no

# %% [markdown]
# # train_test_split

# %%
# %run "common_imports.py"

df = pd.read_csv("../data/02.csv")
features = df.drop(columns=["is_canceled"])
target = df["is_canceled"]

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20, random_state=0)

display(X_train.head(), "")
display(y_train.head(), "")
# Out:
#         lead_time  arrival_date_week_number  arrival_date_day_of_month  \
# 104182         23                         2                         11
# 110320        102                        17                         24
# 60388         489                        46                         10
# 105591         36                         7                         12
# 73207         101                        33                         17
#
#         arrival_date_month  stays_in_weekend_nights  stays_in_week_nights  \
# 104182                   1                        0                     0
# 110320                   4                        1                     3
# 60388                   11                        0                     2
# 105591                   2                        2                     1
# 73207                    8                        1                     3
#
#         adults  children  babies  is_repeated_guest  ...  \
# ...

# %% [markdown]
# ## KNN classification
#
# - 1st attempt: 1 neighbor,  accuracy 77.46%
# - 2nd attempt: **2 neighbors, accuracy 79.04%**
# - 3rd attempt: 3 neighbors, accuracy 77.33%
# - 4th attempt: 4 neighbors, accuracy 78.29%
# - 5th attempt: 5 neighbors, accuracy 77.20%

# %%
knn = KNeighborsClassifier(n_neighbors=2)
display(knn.fit(X_train, y_train))

pred = knn.predict(X_test)
print(f"The accuracy of the model is {knn.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred = pred, y_true = y_test), "\n")
# Out:
# KNeighborsClassifier(n_neighbors=2)
# The accuracy of the model is 79.04%
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.85     14940
#            1       0.81      0.57      0.67      8902
#
#     accuracy                           0.79     23842
#    macro avg       0.80      0.75      0.76     23842
# weighted avg       0.79      0.79      0.78     23842

# %% [markdown]
# ## Logistic regression
# - max_iter=4000 (1000-3000 wasn't enough), **score 80.84%**
# - top 5 features by absolute coefficient
#   - required_car_parking_spaces 6.26
#   - deposit_type_Non_Refund 3.46
#   - previous_cancellations 2.83
#   - deposit_type_No_Deposit 2.15
#   - deposit_type_Refundable 1.52

# %%
log_reg = LogisticRegression(max_iter=4000)
display(log_reg.fit(X_train, y_train), "")

pred = log_reg.predict(X_test)

print(f"Logistic Regression score is {log_reg.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")

# individual coefficients
coefficients = log_reg.coef_[0]
feature_names = X_train.columns
coefficients_df = pd.DataFrame({"Feature": feature_names, "Coefficient": coefficients})
coefficients_df["Absolute Coefficient"] = abs(coefficients_df["Coefficient"])
coefficients_df[["Coefficient", "Absolute Coefficient"]] = coefficients_df[["Coefficient", "Absolute Coefficient"]].round(2)
coefficients_df = coefficients_df.sort_values(by="Absolute Coefficient", ascending=False)
display(coefficients_df)
# Out:
# LogisticRegression(max_iter=4000)
# ''
# Logistic Regression score is 80.84%
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86     14940
#            1       0.85      0.59      0.70      8902
#
#     accuracy                           0.81     23842
#    macro avg       0.82      0.76      0.78     23842
# weighted avg       0.81      0.81      0.80     23842
#                            Feature  Coefficient  Absolute Coefficient
# 12     required_car_parking_spaces        -6.26                  6.26
# 44         deposit_type_Non_Refund         3.46                  3.46
# 10          previous_cancellations         2.83                  2.83
# 43         deposit_type_No_Deposit        -2.15                  2.15
# 45         deposit_type_Refundable        -1.52                  1.52
# 15               booked_by_company        -1.17                  1.17
# 28    market_segment_Offline_TA_TO        -0.83                  0.83
# ...

# %% [markdown]
# ## Decision tree
# - **score 81,93%**
# - **tree importance**:
#   - 'deposit_type_Non_Refund': '0.50',
#   - 'lead_time': '0.10',
#   - 'total_of_special_requests': '0.10',
#   - 'market_segment_Online_TA': '0.08',
#   - 'previous_cancellations': '0.07',
#   - 'required_car_parking_spaces': '0.04',
#   - 'customer_type_Transient': '0.03',
#   - 'avg_daily_rate': '0.02',
#   - 'arrival_date_week_number': '0.01',
#   - 'adults': '0.01',
#   - 'previous_bookings_not_canceled': '0.01',

# %%
tree = DecisionTreeClassifier(max_depth=10)
display(tree.fit(X_train, y_train), "")

pred = tree.predict(X_test)

print(f"Decision Tree accuracy is {tree.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")

tree_importance = {feature: f"{importance:.2f}" for feature, importance in zip(X_train.columns, tree.feature_importances_)}
sorted_tree_importance = {k: v for k, v in sorted(tree_importance.items(), key=lambda item: item[1], reverse=True)}
display(sorted_tree_importance, "")

tree = DecisionTreeClassifier(max_depth=2)
tree.fit(X_train, y_train)

dot_data = export_graphviz(tree, out_file="tree.dot", filled=True, rounded=True, feature_names=X_train.columns)

with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
# Out:
# DecisionTreeClassifier(max_depth=10)
# ''
# Decision Tree accuracy is 81.94%
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87     14940
#            1       0.84      0.63      0.72      8902
#
#     accuracy                           0.82     23842
#    macro avg       0.83      0.78      0.79     23842
# weighted avg       0.82      0.82      0.81     23842
# {'deposit_type_Non_Refund': '0.50',
#  'lead_time': '0.10',
#  'total_of_special_requests': '0.10',
#  'market_segment_Online_TA': '0.08',
#  'previous_cancellations': '0.07',
#  'required_car_parking_spaces': '0.04',
#  'customer_type_Transient': '0.03',
#  'avg_daily_rate': '0.02',
#  'arrival_date_week_number': '0.01',
#  'adults': '0.01',
#  'previous_bookings_not_canceled': '0.01',
#  'hotel_City': '0.01',
#  'arrival_date_day_of_month': '0.00',
#  'arrival_date_month': '0.00',
#  'stays_in_weekend_nights': '0.00',
#  'stays_in_week_nights': '0.00',
# ...

# %% [markdown]
# ## Ensemble

# %% [markdown]
# ### Bagging
# - n_estimators=100, max_samples = 1000, what's the accuracy?
# - KNeighborsClassifier(n_neighbors=2), 70.80%
# - LogisticRegression(max_iter=4000), 80.90%, **computation takes 12m, while other estimators take seconds**
# - **DecisionTreeClassifier(max_depth=10), 81.74%**
# - RandomForestClassifier, 81.40%
# - AdaBoostClassifier, "divide by zero encountered"
# - GradientBoostingClassifier, 81.31%

# %%
bagging_knn = BaggingClassifier(KNeighborsClassifier(n_neighbors=2), n_estimators=100, max_samples=1000)
display(bagging_knn.fit(X_train, y_train), "")
pred = bagging_knn.predict(X_test)

print(f"Bagging KNN accuracy is {bagging_knn.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")
# Out:
# BaggingClassifier(estimator=KNeighborsClassifier(n_neighbors=2),
#                   max_samples=1000, n_estimators=100)
# ''
# Bagging KNN accuracy is 70.86%
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.89      0.79     14940
#            1       0.68      0.41      0.51      8902
#
#     accuracy                           0.71     23842
#    macro avg       0.70      0.65      0.65     23842
# weighted avg       0.70      0.71      0.69     23842

# %%
bagging_log_reg = BaggingClassifier(LogisticRegression(max_iter=4000), n_estimators=100, max_samples=1000, verbose=3)
display(bagging_log_reg.fit(X_train, y_train), "")
pred = bagging_log_reg.predict(X_test)

print(f"Bagging LR accuracy is {bagging_log_reg.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")
# Out:
# Building estimator 1 of 100 for this parallel run (total 100)...
# Building estimator 2 of 100 for this parallel run (total 100)...
# Building estimator 3 of 100 for this parallel run (total 100)...
# Building estimator 4 of 100 for this parallel run (total 100)...
# Building estimator 5 of 100 for this parallel run (total 100)...
# Building estimator 6 of 100 for this parallel run (total 100)...
# Building estimator 7 of 100 for this parallel run (total 100)...
# Building estimator 8 of 100 for this parallel run (total 100)...
# Building estimator 9 of 100 for this parallel run (total 100)...
# Building estimator 10 of 100 for this parallel run (total 100)...
# Building estimator 11 of 100 for this parallel run (total 100)...
# Building estimator 12 of 100 for this parallel run (total 100)...
# Building estimator 13 of 100 for this parallel run (total 100)...
# Building estimator 14 of 100 for this parallel run (total 100)...
# ...

# %%
bagging_dt = BaggingClassifier(DecisionTreeClassifier(max_depth=10), n_estimators=100, max_samples = 1000)
display(bagging_dt.fit(X_train, y_train), "")
pred = bagging_dt.predict(X_test)

print(f"Bagging DT accuracy is {bagging_dt.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(max_depth=10),
#                   max_samples=1000, n_estimators=100)
# ''
# Bagging DT accuracy is 81.63%
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86     14940
#            1       0.85      0.61      0.71      8902
#
#     accuracy                           0.82     23842
#    macro avg       0.83      0.78      0.79     23842
# weighted avg       0.82      0.82      0.81     23842

# %%
bagging_rf = BaggingClassifier(RandomForestClassifier(), n_estimators=100, max_samples=1000, verbose=3)
display(bagging_rf.fit(X_train, y_train), "")
pred_rf = bagging_rf.predict(X_test)

print(f"Bagging RF accuracy is {bagging_rf.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred_rf, y_true=y_test), "\n")
# Out:
# Building estimator 1 of 100 for this parallel run (total 100)...
# Building estimator 2 of 100 for this parallel run (total 100)...
# Building estimator 3 of 100 for this parallel run (total 100)...
# Building estimator 4 of 100 for this parallel run (total 100)...
# Building estimator 5 of 100 for this parallel run (total 100)...
# Building estimator 6 of 100 for this parallel run (total 100)...
# Building estimator 7 of 100 for this parallel run (total 100)...
# Building estimator 8 of 100 for this parallel run (total 100)...
# Building estimator 9 of 100 for this parallel run (total 100)...
# Building estimator 10 of 100 for this parallel run (total 100)...
# Building estimator 11 of 100 for this parallel run (total 100)...
# Building estimator 12 of 100 for this parallel run (total 100)...
# Building estimator 13 of 100 for this parallel run (total 100)...
# Building estimator 14 of 100 for this parallel run (total 100)...
# ...

# %%
bagging_gb = BaggingClassifier(GradientBoostingClassifier(), n_estimators=100, max_samples=1000, verbose=3)
display(bagging_gb.fit(X_train, y_train), "")
pred_gb = bagging_gb.predict(X_test)

print(f"Bagging Gradient Boosting accuracy is {bagging_gb.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred_gb, y_true=y_test), "\n")
# Out:
# Building estimator 1 of 100 for this parallel run (total 100)...
# Building estimator 2 of 100 for this parallel run (total 100)...
# Building estimator 3 of 100 for this parallel run (total 100)...
# Building estimator 4 of 100 for this parallel run (total 100)...
# Building estimator 5 of 100 for this parallel run (total 100)...
# Building estimator 6 of 100 for this parallel run (total 100)...
# Building estimator 7 of 100 for this parallel run (total 100)...
# Building estimator 8 of 100 for this parallel run (total 100)...
# Building estimator 9 of 100 for this parallel run (total 100)...
# Building estimator 10 of 100 for this parallel run (total 100)...
# Building estimator 11 of 100 for this parallel run (total 100)...
# Building estimator 12 of 100 for this parallel run (total 100)...
# Building estimator 13 of 100 for this parallel run (total 100)...
# Building estimator 14 of 100 for this parallel run (total 100)...
# ...

# %% [markdown]
# ### RandomForest
# - **score 81.74%**

# %%
random_forest = RandomForestClassifier(n_estimators=100, max_samples=1000)
display(random_forest.fit(X_train, y_train), "")
pred_rf = random_forest.predict(X_test)

print(f"Random Forest accuracy is {random_forest.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred_rf, y_true=y_test), "\n")
# Out:
# RandomForestClassifier(max_samples=1000)
# ''
# Random Forest accuracy is 81.82%
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87     14940
#            1       0.87      0.60      0.71      8902
#
#     accuracy                           0.82     23842
#    macro avg       0.84      0.77      0.79     23842
# weighted avg       0.83      0.82      0.81     23842

# %% [markdown]
# ### AdaBoost
# - n_estimators=100, algorithm='SAMME'
# - KNN doesn't work
# - LogisticRegression(max_iter=4000), 77.96%, same result even for max_iter=1000
# - **DecisionTreeClassifier(max_depth=20), 85.49%, ct 1m**
# - RandomForestClassifier(max_depth=20), 85.93%, ct 7m
# - GradientBoostingClassifier(), 83.59%, ct 7m
# - GradientBoostingClassifier(max_depth=20) won't execute

# %%
ada_log_reg = AdaBoostClassifier(LogisticRegression(max_iter=1000), n_estimators=100, algorithm='SAMME')
display(ada_log_reg.fit(X_train, y_train), "")
pred = ada_log_reg.predict(X_test)

print(f"AdaBoost LR accuracy is {ada_log_reg.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    estimator=LogisticRegression(max_iter=1000),
#                    n_estimators=100)
# ''
# AdaBoost LR accuracy is 77.96%
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83     14940
#            1       0.74      0.64      0.68      8902
#
#     accuracy                           0.78     23842
#    macro avg       0.77      0.75      0.76     23842
# weighted avg       0.78      0.78      0.78     23842

# %%
ada_dt = AdaBoostClassifier(DecisionTreeClassifier(max_depth=20), n_estimators=100, algorithm='SAMME')
display(ada_dt.fit(X_train, y_train), "")
pred = ada_dt.predict(X_test)

print(f"AdaBoost DT accuracy is {ada_dt.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    estimator=DecisionTreeClassifier(max_depth=20),
#                    n_estimators=100)
# ''
# AdaBoost DT accuracy is 85.47%
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89     14940
#            1       0.84      0.76      0.80      8902
#
#     accuracy                           0.85     23842
#    macro avg       0.85      0.83      0.84     23842
# weighted avg       0.85      0.85      0.85     23842

# %%
ada_rf = AdaBoostClassifier(RandomForestClassifier(max_depth=20), n_estimators=100, algorithm='SAMME')
display(ada_rf.fit(X_train, y_train), "")
pred = ada_rf.predict(X_test)

print(f"AdaBoost RF accuracy is {ada_rf.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    estimator=RandomForestClassifier(max_depth=20),
#                    n_estimators=100)
# ''
# AdaBoost RF accuracy is 85.98%
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89     14940
#            1       0.87      0.73      0.80      8902
#
#     accuracy                           0.86     23842
#    macro avg       0.86      0.83      0.84     23842
# weighted avg       0.86      0.86      0.86     23842

# %%
ada_gb = AdaBoostClassifier(GradientBoostingClassifier(max_depth=10), n_estimators=100, algorithm='SAMME')
display(ada_gb.fit(X_train, y_train), "")
pred_gb = ada_gb.predict(X_test)

print(f"AdaBoost GB accuracy is {ada_gb.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred_gb, y_true=y_test), "\n")
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    estimator=GradientBoostingClassifier(max_depth=10),
#                    n_estimators=100)
# ''
# AdaBoost GB accuracy is 85.86%
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89     14940
#            1       0.85      0.76      0.80      8902
#
#     accuracy                           0.86     23842
#    macro avg       0.86      0.84      0.85     23842
# weighted avg       0.86      0.86      0.86     23842

# %%
ada_gb = AdaBoostClassifier(GradientBoostingClassifier(max_depth=20), n_estimators=100, algorithm='SAMME')
display(ada_gb.fit(X_train, y_train), "")
pred_gb = ada_gb.predict(X_test)

print(f"AdaBoost GB accuracy is {ada_gb.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred_gb, y_true=y_test), "\n")
# Out:
# KeyboardInterrupt

# %%
ada_gb = AdaBoostClassifier(GradientBoostingClassifier(), n_estimators=100, algorithm='SAMME')
display(ada_gb.fit(X_train, y_train), "")
pred_gb = ada_gb.predict(X_test)

print(f"AdaBoost GB accuracy is {ada_gb.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred_gb, y_true=y_test), "\n")
# Out:
# AdaBoostClassifier(algorithm='SAMME', estimator=GradientBoostingClassifier(),
#                    n_estimators=100)
# ''
# AdaBoost GB accuracy is 83.58%
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87     14940
#            1       0.83      0.70      0.76      8902
#
#     accuracy                           0.84     23842
#    macro avg       0.83      0.81      0.82     23842
# weighted avg       0.84      0.84      0.83     23842

# %% [markdown]
# ### GradientBoosting
# - **81.49%**

# %%
gb_clf = GradientBoostingClassifier(n_estimators=100)
display(gb_clf.fit(X_train, y_train), "")
pred = gb_clf.predict(X_test)

print(f"Gradient Boosting accuracy is {gb_clf.score(X_test, y_test) * 100:.2f}%\n")
print(classification_report(y_pred=pred, y_true=y_test), "\n")
# Out:
# GradientBoostingClassifier()
# ''
# Gradient Boosting accuracy is 81.49%
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86     14940
#            1       0.84      0.62      0.72      8902
#
#     accuracy                           0.81     23842
#    macro avg       0.82      0.78      0.79     23842
# weighted avg       0.82      0.81      0.81     23842
